# %%
import pandas as pd

# %%
fName = "busan_temp_20211101152204.csv"
df = pd.read_csv(fName,encoding="cp949",skiprows=10)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4276/2145559428.py in <module>
#       1 fName = "busan_temp_20211101152204.csv"
# ----> 2 df = pd.read_csv(fName,encoding="cp949",skiprows=10)
#       3 df.head()
#
# NameError: name 'pd' is not defined

# %%
fName = "busan_temp_20211101152204.csv"
df = pd.read_csv(fName, encoding="cp949", skiprows=11,index_col = 2, 
names=['지점번호','지점명','일시','평균기온','평균최고기온','최고기온','최고기온일자','평균최저기온','최저기온','최저기온일자'])
df.head(2)
# Out:
#             지점번호 지점명  평균기온  평균최고기온  최고기온      최고기온일자  평균최저기온  최저기온      최저기온일자
# 일시
# 2020-01  \t\t159  부산   6.4    10.9  17.7  2020-01-07     3.1  -3.2  2020-01-01
# 2020-02  \t\t159  부산   7.1    11.8  18.1  2020-02-14     3.1  -5.0  2020-02-06

# %%
df.tail(3)
# Out:
#      지점번호  지점명  평균기온  평균최고기온  최고기온 최고기온일자  평균최저기온  최저기온 최저기온일자
# 일시
# NaN  \t\t  NaN   NaN     NaN   NaN    NaN     NaN   NaN    NaN
# NaN    \t  NaN   NaN     NaN   NaN    NaN     NaN   NaN    NaN
# NaN    \t  NaN   NaN     NaN   NaN    NaN     NaN   NaN    NaN

# %%
df.value_counts(dropna=False) #dropna=False : NaN값을 포함하여 누락된 데이터의 갯수 파악
# Out:
# 지점번호     지점명  평균기온  평균최고기온  최고기온  최고기온일자      평균최저기온  최저기온   최저기온일자
# \t       NaN  NaN   NaN     NaN   NaN          NaN     NaN   NaN           6
# \t\t     NaN  NaN   NaN     NaN   NaN          NaN     NaN   NaN           2
# \t\t159  부산   26.3  29.5    32.4  2021-07-20   24.0    20.8  2021-07-05    1
#               26.2  29.4    35.6  2021-08-06   23.8    20.4  2021-08-17    1
#               22.9  26.4    28.8  2021-09-12   20.5    18.9  2021-09-27    1
#               22.4  26.6    30.7  2020-06-28   19.5    16.8  2020-06-18    1
#               22.1  24.8    30.6  2020-07-31   20.3    17.8  2020-07-17    1
#               21.9  25.6    30.6  2020-09-01   19.2    15.5  2020-09-29    1
#                     25.4    30.9  2021-06-21   19.3    16.6  2021-06-01    1
#               18.7  23.3    28.4  2021-10-10   15.2    5.5   2021-10-17    1
#               17.9  21.8    26.0  2020-05-27   15.0    12.2  2020-05-22    1
# ...

# %%
df = df.dropna(axis=0, thresh=9) # 9개 이상의 유효한 데이터가 아닌 행 삭제 
df.tail()
# Out:
#             지점번호 지점명  평균기온  평균최고기온  최고기온      최고기온일자  평균최저기온  최저기온      최저기온일자
# 일시
# 2021-06  \t\t159  부산  21.9    25.4  30.9  2021-06-21    19.3  16.6  2021-06-01
# 2021-07  \t\t159  부산  26.3    29.5  32.4  2021-07-20    24.0  20.8  2021-07-05
# 2021-08  \t\t159  부산  26.2    29.4  35.6  2021-08-06    23.8  20.4  2021-08-17
# 2021-09  \t\t159  부산  22.9    26.4  28.8  2021-09-12    20.5  18.9  2021-09-27
# 2021-10  \t\t159  부산  18.7    23.3  28.4  2021-10-10    15.2   5.5  2021-10-17

# %%
df.value_counts()
# Out:
# 지점번호     지점명  평균기온  평균최고기온  최고기온  최고기온일자      평균최저기온  최저기온   최저기온일자
# \t\t159  부산   3.3   7.9     15.7  2021-01-15  -0.8    -12.2  2021-01-08    1
#               4.3   9.3     15.0  2020-12-28   0.5    -8.0   2020-12-31    1
#               26.3  29.5    32.4  2021-07-20   24.0    20.8  2021-07-05    1
#               26.2  29.4    35.6  2021-08-06   23.8    20.4  2021-08-17    1
#               22.9  26.4    28.8  2021-09-12   20.5    18.9  2021-09-27    1
#               22.4  26.6    30.7  2020-06-28   19.5    16.8  2020-06-18    1
#               22.1  24.8    30.6  2020-07-31   20.3    17.8  2020-07-17    1
#               21.9  25.6    30.6  2020-09-01   19.2    15.5  2020-09-29    1
#                     25.4    30.9  2021-06-21   19.3    16.6  2021-06-01    1
#               18.7  23.3    28.4  2021-10-10   15.2    5.5   2021-10-17    1
#               17.9  21.8    26.0  2020-05-27   15.0    12.2  2020-05-22    1
# ...

# %%
df.head(3)
# Out:
#             지점번호 지점명  평균기온  평균최고기온  최고기온      최고기온일자  평균최저기온  최저기온      최저기온일자
# 일시
# 2020-01  \t\t159  부산   6.4    10.9  17.7  2020-01-07     3.1  -3.2  2020-01-01
# 2020-02  \t\t159  부산   7.1    11.8  18.1  2020-02-14     3.1  -5.0  2020-02-06
# 2020-03  \t\t159  부산  10.4    15.0  18.2  2020-03-19     6.4  -0.3  2020-03-05

# %%
df.__setitem__('지점번호',df.__getitem__('지점번호').replace("\t",""))
df.head()
# Out:
#             지점번호 지점명  평균기온  평균최고기온  최고기온      최고기온일자  평균최저기온  최저기온      최저기온일자
# 일시
# 2020-01  \t\t159  부산   6.4    10.9  17.7  2020-01-07     3.1  -3.2  2020-01-01
# 2020-02  \t\t159  부산   7.1    11.8  18.1  2020-02-14     3.1  -5.0  2020-02-06
# 2020-03  \t\t159  부산  10.4    15.0  18.2  2020-03-19     6.4  -0.3  2020-03-05
# 2020-04  \t\t159  부산  12.6    17.5  24.4  2020-04-29     8.9   4.4  2020-04-23
# 2020-05  \t\t159  부산  17.9    21.8  26.0  2020-05-27    15.0  12.2  2020-05-22

# %%
def removeData(rData):
    #print(rData)
    return rData.replace("\t","")

# df['지점번호'] = df['지점번호'].apply(removeData)
df['지점번호'] = df['지점번호'].str.replace("\t","")
df.head(2)
# Out:
#         지점번호 지점명  평균기온  평균최고기온  최고기온      최고기온일자  평균최저기온  최저기온      최저기온일자
# 일시
# 2020-01  159  부산   6.4    10.9  17.7  2020-01-07     3.1  -3.2  2020-01-01
# 2020-02  159  부산   7.1    11.8  18.1  2020-02-14     3.1  -5.0  2020-02-06

# %%
# 최고기온 
print(f"최고기온{max(df['최고기온'])}")
df['최고기온'].head()
# Out:
# 최고기온35.6
# 일시
# 2020-01    17.7
# 2020-02    18.1
# 2020-03    18.2
# 2020-04    24.4
# 2020-05    26.0
# Name: 최고기온, dtype: float64

# %%
# 최저기온 
print(f"최고기온{min(df['최저기온'])}")
df['최저기온'].head()
# Out:
# 최고기온15.0
# 일시
# 2020-01    17.7
# 2020-02    18.1
# 2020-03    18.2
# 2020-04    24.4
# 2020-05    26.0
# Name: 최고기온, dtype: float64

# %%
# 최저기온 
print(f"최고기온{min(df['최저기온'])}")
df['최저기온'].head()

# %%
df['최저기온'].sort_values()
# Out:
# 일시
# 2021-01   -12.2
# 2020-12    -8.0
# 2021-02    -7.2
# 2020-02    -5.0
# 2020-01    -3.2
# 2020-03    -0.3
# 2020-11     1.1
# 2021-03     1.6
# 2020-04     4.4
# 2021-10     5.5
# 2021-04     6.3
# 2020-10     7.0
# 2021-05     8.6
# 2020-05    12.2
# 2020-09    15.5
# 2021-06    16.6
# 2020-06    16.8
# 2020-07    17.8
# 2021-09    18.9
# 2021-08    20.4
# 2021-07    20.8
# 2020-08    23.4
# Name: 최저기온, dtype: float64

# %%
df.index[df['최고기온'] == max(df['최고기온'])]
# Out:
# Index(['2021-08'], dtype='object', name='일시')

# %%
df['최고기온'].sort_values()
# Out:
# 일시
# 2020-12    15.0
# 2021-01    15.7
# 2020-01    17.7
# 2020-02    18.1
# 2020-03    18.2
# 2021-02    19.3
# 2021-03    21.6
# 2020-11    23.3
# 2020-04    24.4
# 2020-10    25.9
# 2020-05    26.0
# 2021-04    26.5
# 2021-05    26.5
# 2021-10    28.4
# 2021-09    28.8
# 2020-09    30.6
# 2020-07    30.6
# 2020-06    30.7
# 2021-06    30.9
# 2021-07    32.4
# 2020-08    33.2
# 2021-08    35.6
# Name: 최고기온, dtype: float64

# %%
print(f"가장 더웠던 달:{df.index[df['최고기온'] == max(df['최고기온'])][0]}")
# Out:
# 가장 더웠던 달:2021-08

# %%
# 최저기온mean(평균값)
print(f"최저기온:{min(df['최저기온'])}")
print(f"가장 추웠던 달:{df.index[df['최저기온'] == min(df['최저기온'])][0]}")
# Out:
# 최저기온:-12.2
# 가장 추웠던 달:2021-01

# %%
# 평균 기온이 25도 넘는 달은?
df.loc[df['평균기온'] > 25]
# Out:
#         지점번호 지점명  평균기온  평균최고기온  최고기온      최고기온일자  평균최저기온  최저기온      최저기온일자
# 일시
# 2020-08  159  부산  27.2    30.4  33.2  2020-08-20    24.8  23.4  2020-08-27
# 2021-07  159  부산  26.3    29.5  32.4  2021-07-20    24.0  20.8  2021-07-05
# 2021-08  159  부산  26.2    29.4  35.6  2021-08-06    23.8  20.4  2021-08-17

# %%
# 평균 기온이 25도 넘는 달은?
df.index[df['평균기온'] > 25].tolist()
# Out:
# ['2020-08', '2021-07', '2021-08']

# %%
import matplotlib.pyplot as plt

# %%
# 한글 폰트 설정
plt.rc('font', family="HYGothic-Medium")

# %%
from matplotlib import font_manager, rc
plt.rcParams["font.size"] = 14
plt.figure(figsize=(25,8))
plt.plot(df.index,df["최고기온"], c="r")
plt.xticks(rotation=90)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(25,8))
plt.plot(df.index,df["최고기온"], c="r",marker="^")
plt.plot(df.index,df["최저기온"], c="b",marker="v")
plt.xticks(rotation=90)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
# C:\python_3_8_8\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\python_3_8_8\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
