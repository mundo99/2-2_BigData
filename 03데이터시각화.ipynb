# %%
import pandas as pd

# %%
fileName = "systolic.csv"
df = pd.read_csv(fileName)
df

# %%
import matplotlib.font_manager as fm
result = ""
for fontInfo in fm.fontManager.ttflist:
    if 'Gothic' in fontInfo.name:
        print(fontInfo.name,"=", fontInfo.fname)

# %%
import matplotlib.pyplot as plt
plt.rc('font', family ="HYGothic-Medium")

# %%
df.plot()

# %%
df.head(3)

# %%
df2 = df.set_index("이름")
df2 = df2.iloc[:,-5:]
df2.head()

# %%
df2.plot(figsize=(16,6))

# %%
df3 = df.set_index("이름")
df3 = df3.iloc[:3,4:7]
df3.head()

# %%
df3.plot(kind="bar")

# %%
lstColor = ["pink","g","skyblue"]
df3.plot(kind="bar", color=lstColor)

# %%
df3

# %%
df3 = df.set_index("이름")
df3 = df3.iloc[:,4:7]
df3.head()

# %%
df3.plot()
plt.legend(loc="best")

# %%
df3.plot(title="키와 체중 그리고BMI")
plt.legend(loc="lower right")

# %%
df3.plot(kind="bar", color=lstColor, stacked=True)

# %%
df3.plot(kind="box")

# %%
df3.plot()

# %%
df3["키"].plot(ls="--",c="blue",marker="^")
df3["체중"].plot(linestyle=":",color="m",marker="o")
df3["BMI"].plot(grid=True)
plt.legend()  # 범례 표시

# %%
df3.head(2)
# Out:
#        키  체중   BMI
# 이름
# 이겨레  181  76  23.2
# 조약돌  185  89  26.0

# %%
df3.loc["오대양"]
# Out:
# 키      193.0
# 체중      95.0
# BMI     25.5
# Name: 오대양, dtype: float64

# %%
plt.rc("font", size=25)
lstColor=["pink","#e35f62",'skyblue']
webgeprops={"width":1, 'edgecolor':'w','linewidth':5}
df3.loc["오대양"].plot(kind="pie",figsize=(8,8),title="오대양의 BMI정보",
autopct="%.1f%%",colors=lstColor)
plt.legend(loc=(0.9,0.8))
plt.savefig('imGrape.jpg',bbox_inches="tight") # 여백을 타이트하게
