# %%
import pandas as pd

# %%
fName = "서울시 코로나19 확진자 현황_utf8.csv"
df = pd.read_csv(fName)
df.head(6)
# Out:
# C:\python_3_8_8\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        연번         확진일  환자번호  국적  환자정보   지역  여행력        접촉력  조치사항 상태 이동경로  \
# 0  132668  2021-11-14   NaN NaN   NaN  금천구  NaN   감염경로 조사중   NaN  -  NaN
# 1  132667  2021-11-14   NaN NaN   NaN  강동구  NaN  기타 확진자 접촉   NaN  -  NaN
# 2  132666  2021-11-14   NaN NaN   NaN  강서구  NaN  기타 확진자 접촉   NaN  -  NaN
# 3  132665  2021-11-14   NaN NaN   NaN  서초구  NaN  기타 확진자 접촉   NaN  -  NaN
# 4  132664  2021-11-14   NaN NaN   NaN  타시도  NaN  기타 확진자 접촉   NaN  -  NaN
# 5  132663  2021-11-14   NaN NaN   NaN  강서구  NaN  기타 확진자 접촉   NaN  -  NaN
#
#                등록일              수정일 노출여부
# 0  2021-11-15 9:36  2021-11-15 9:36    Y
# 1  2021-11-15 9:36  2021-11-15 9:36    Y
# 2  2021-11-15 9:36  2021-11-15 9:36    Y
# 3  2021-11-15 9:36  2021-11-15 9:36    Y
# 4  2021-11-15 9:36  2021-11-15 9:36    Y
# 5  2021-11-15 9:36  2021-11-15 9:36    Y

# %%
# 데이터 정보 확인
print("데이터의 크기:", df.shape)
print("데이터의 타입:", df.dtypes)
print("데이터의 컬럼명(필드):", df.columns)
print("데이터의 인덱스명:", df.index)
# Out:
# 데이터의 크기: (132668, 14)
# 데이터의 타입: 연번        int64
# 확진일      object
# 환자번호    float64
# 국적      float64
# 환자정보    float64
# 지역       object
# 여행력      object
# 접촉력      object
# 조치사항    float64
# 상태       object
# 이동경로     object
# 등록일      object
# 수정일      object
# 노출여부     object
# dtype: object
# 데이터의 컬럼명(필드): Index(['연번', '확진일', '환자번호', '국적', '환자정보', '지역', '여행력', '접촉력', '조치사항', '상태',
#        '이동경로', '등록일', '수정일', '노출여부'],
#       dtype='object')
# 데이터의 인덱스명: RangeIndex(start=0, stop=132668, step=1)

# %%
# 결측치 데이터 삭제
df.dropna(axis=1, inplace=True)
df.head(3)
# Out:
#        연번         확진일   지역        접촉력 상태              등록일              수정일  \
# 0  132668  2021-11-14  금천구   감염경로 조사중  -  2021-11-15 9:36  2021-11-15 9:36
# 1  132667  2021-11-14  강동구  기타 확진자 접촉  -  2021-11-15 9:36  2021-11-15 9:36
# 2  132666  2021-11-14  강서구  기타 확진자 접촉  -  2021-11-15 9:36  2021-11-15 9:36
#
#   노출여부
# 0    Y
# 1    Y
# 2    Y

# %%
df.tail(3)
# Out:
#         연번         확진일   지역       접촉력  상태               등록일               수정일  \
# 132665   3  2020-01-30  종로구  종로구 집단발병  퇴원  2021-05-27 11:08  2021-05-27 11:08
# 132666   2  2020-01-30  중랑구      해외유입  퇴원  2021-05-27 11:08  2021-05-27 11:08
# 132667   1  2020-01-24  강서구      해외유입  퇴원  2021-05-27 11:08  2021-05-27 11:08
#
#        노출여부
# 132665    Y
# 132666    Y
# 132667    Y

# %%
df["확진일"]
# Out:
# 0         2021-11-14
# 1         2021-11-14
# 2         2021-11-14
# 3         2021-11-14
# 4         2021-11-14
#              ...
# 132663    2020-01-31
# 132664    2020-01-30
# 132665    2020-01-30
# 132666    2020-01-30
# 132667    2020-01-24
# Name: 확진일, Length: 132668, dtype: object

# %%
# 데이터 전처리
date = "2021-11-14"
# 년 - 월 - 일
date = date.split("-")
print("date =", date)
print(date[0])
print(date[1])
print(date[2])
# Out:
# date = ['2021', '11', '14']
# 2021
# 11
# 14

# %%
# 확진일에서 년,월,일 분리하여 저장
df["year"] = df["확진일"].apply(lambda x:x.split("-")[0]) # 년[0]
df["month"] = df["확진일"].apply(lambda x:x.split("-")[1]) # 월[1]
df["day"] = df["확진일"].apply(lambda x:x.split("-")[2]) # 일[3]
df.head()
# Out:
#        연번         확진일   지역        접촉력 상태              등록일              수정일  \
# 0  132668  2021-11-14  금천구   감염경로 조사중  -  2021-11-15 9:36  2021-11-15 9:36
# 1  132667  2021-11-14  강동구  기타 확진자 접촉  -  2021-11-15 9:36  2021-11-15 9:36
# 2  132666  2021-11-14  강서구  기타 확진자 접촉  -  2021-11-15 9:36  2021-11-15 9:36
# 3  132665  2021-11-14  서초구  기타 확진자 접촉  -  2021-11-15 9:36  2021-11-15 9:36
# 4  132664  2021-11-14  타시도  기타 확진자 접촉  -  2021-11-15 9:36  2021-11-15 9:36
#
#   노출여부  year month day
# 0    Y  2021    11  14
# 1    Y  2021    11  14
# 2    Y  2021    11  14
# 3    Y  2021    11  14
# 4    Y  2021    11  14

# %%
# year, month, day를 object(string) --> int로 변환하는 과정
df["year"] = pd.to_numeric(df["year"])
df["month"] = pd.to_numeric(df["month"])
df["day"] = pd.to_numeric(df["day"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132668 entries, 0 to 132667
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   연번      132668 non-null  int64
#  1   확진일     132668 non-null  object
#  2   지역      132668 non-null  object
#  3   접촉력     132668 non-null  object
#  4   상태      132668 non-null  object
#  5   등록일     132668 non-null  object
#  6   수정일     132668 non-null  object
#  7   노출여부    132668 non-null  object
#  8   year    132668 non-null  int64
#  9   month   132668 non-null  int64
#  10  day     132668 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 11.1+ MB

# %%
df21 = df[df["year"] == 2021]
df21.tail(3)
# Out:
#            연번         확진일   지역        접촉력  상태               등록일  \
# 113312  19356  2021-01-01  금천구  기타 확진자 접촉  퇴원  2021-05-27 11:08
# 113313  19355  2021-01-01  동작구   감염경로 조사중  퇴원  2021-05-27 11:08
# 113314  19354  2021-01-01  성동구   감염경로 조사중  퇴원  2021-05-27 11:08
#
#                      수정일 노출여부  year  month  day
# 113312  2021-05-27 11:08    Y  2021      1    1
# 113313  2021-05-27 11:08    Y  2021      1    1
# 113314  2021-05-27 11:08    Y  2021      1    1

# %%
df20 = df[df["year"] == 2020]
df20.tail(3)
# Out:
#         연번         확진일   지역       접촉력  상태               등록일               수정일  \
# 132665   3  2020-01-30  종로구  종로구 집단발병  퇴원  2021-05-27 11:08  2021-05-27 11:08
# 132666   2  2020-01-30  중랑구      해외유입  퇴원  2021-05-27 11:08  2021-05-27 11:08
# 132667   1  2020-01-24  강서구      해외유입  퇴원  2021-05-27 11:08  2021-05-27 11:08
#
#        노출여부  year  month  day
# 132665    Y  2020      1   30
# 132666    Y  2020      1   30
# 132667    Y  2020      1   24

# %%
# 20년 월별 확진자 수 
df20M = df20["month"].value_counts().sort_index()
df20M
# Out:
# 1         7
# 2        80
# 3       391
# 4       156
# 5       229
# 6       459
# 7       281
# 8      2415
# 9      1306
# 10      733
# 11     2904
# 12    10432
# Name: month, dtype: int64

# %%
# 21년 월별 확진자 수 
df21M = df21["month"].value_counts().sort_index()
df21M
# Out:
# 1      4878
# 2      4060
# 3      3897
# 4      5803
# 5      6030
# 6      6258
# 7     14504
# 8     15193
# 9     21383
# 10    18840
# 11    12429
# Name: month, dtype: int64

# %%
df20M.max()
# Out:
# 10432

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/10/5b/0479d7d845b5ba410ca702ffcd7f2cd95a14a4dfff1fde2637802b258b9b/seaborn-0.11.2-py3-none-any.whl
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/10/5b/0479d7d845b5ba410ca702ffcd7f2cd95a14a4dfff1fde2637802b258b9b/seaborn-0.11.2-py3-none-any.whl
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/10/5b/0479d7d845b5ba410ca702ffcd7f2cd95a14a4dfff1fde2637802b258b9b/seaborn-0.11.2-py3-none-any.whl
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\python_3_8_8\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "c:\python_3_8_8\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "c:\python_3_8_8\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "c:\python_3_8_8\lib\http\client.py", line 458, in read
#     n = self.readinto(b)
#   File "c:\python_3_8_8\lib\http\client.py", line 502, in readinto
#     n = self.fp.readinto(b)
#   File "c:\python_3_8_8\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "c:\python_3_8_8\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "c:\python_3_8_8\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\cli\base_command.py", line 173, in _main
#     status = self.run(options, args)
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\cli\req_command.py", line 203, in wrapper
#     return func(self, options, args)
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\commands\install.py", line 315, in run
#     requirement_set = resolver.resolve(
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 94, in resolve
#     result = self._result = resolver.resolve(
#   File "c:\python_3_8_8\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 472, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "c:\python_3_8_8\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 341, in resolve
#     self._add_to_criteria(self.state.criteria, r, parent=None)
#   File "c:\python_3_8_8\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 172, in _add_to_criteria
#     if not criterion.candidates:
#   File "c:\python_3_8_8\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 151, in __bool__
#     return bool(self._sequence)
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 140, in __bool__
#     return any(self)
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 128, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 32, in _iter_built
#     candidate = func()
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 204, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 295, in __init__
#     super().__init__(
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 227, in _prepare
#     dist = self._prepare_distribution()
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 305, in _prepare_distribution
#     return self._factory.preparer.prepare_linked_requirement(
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\operations\prepare.py", line 508, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\operations\prepare.py", line 550, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\operations\prepare.py", line 239, in unpack_url
#     file = get_http_url(
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\operations\prepare.py", line 102, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\network\download.py", line 145, in __call__
#     for chunk in chunks:
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\cli\progress_bars.py", line 144, in iter
#     for x in it:
#   File "c:\python_3_8_8\lib\site-packages\pip\_internal\network\utils.py", line 63, in response_chunks
#     for chunk in response.raw.stream(
#   File "c:\python_3_8_8\lib\site-packages\pip\_vendor\urllib3\response.py", line 576, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "c:\python_3_8_8\lib\site-packages\pip\_vendor\urllib3\response.py", line 541, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "c:\python_3_8_8\lib\contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "c:\python_3_8_8\lib\site-packages\pip\_vendor\urllib3\response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\python_3_8_8\python.exe -m pip install --upgrade pip' command.
